# %%
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import SimpleITK as sitk
# import mlflow

# %%
image_labels = pd.read_csv('luna23-ismi-train-set.csv')
image_labels['noduletype'].value_counts().to_frame().style.background_gradient()
# Out:
# <style type="text/css">
# #T_b4bde_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b4bde_row1_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_b4bde_row2_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_b4bde_row3_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_b4bde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4bde_level0_col0" class="col_heading level0 col0" >noduletype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4bde_level0_row0" class="row_heading level0 row0" >Solid</th>
#       <td id="T_b4bde_row0_col0" class="data row0 col0" >466</td>
#     </tr>
#     <tr>
#       <th id="T_b4bde_level0_row1" class="row_heading level0 row1" >Calcified</th>
#       <td id="T_b4bde_row1_col0" class="data row1 col0" >152</td>
#     </tr>
#     <tr>
#       <th id="T_b4bde_level0_row2" class="row_heading level0 row2" >GroundGlassOpacity</th>
#       <td id="T_b4bde_row2_col0" class="data row2 col0" >51</td>
#     </tr>
#     <tr>
#       <th id="T_b4bde_level0_row3" class="row_heading level0 row3" >SemiSolid</th>
#       <td id="T_b4bde_row3_col0" class="data row3 col0" >18</td>
#     </tr>
#   </tbody>
# </table>

# %%
image_labels[image_labels['noduleid'] == '2.25.10002343616245235850618787121539297713552472755036270141148']
# Out:
#           patientid                                          seriesuid  \
# 136  LIDC-IDRI-0161  1.3.6.1.4.1.14519.5.2.1.6279.6001.189483585244...
#
#                                               noduleid     coordx     coordy  \
# 136  2.25.10002343616245235850618787121539297713552...  90.351712 -71.702854
#
#          coordz  diameter_mm noduletype  malignancy
# 136 -263.880682     9.352996      Solid           0

# %%
# convenience function that returns the axial, coronal and sagittal view given a cube (in numpy format) containing a nodule
def get_orthogonal_patches(x):
    dims = x.shape # Get shape of X
    axial = x[dims[0]//2,:,:]. squeeze()
    coronal = x[:,:,dims[2]//2].squeeze()
    sagittal= x[:,dims[1]//2,:].squeeze()
    return axial, coronal, sagittal

# %%
image = sitk.ReadImage("train_set/images/2.25.10002343616245235850618787121539297713552472755036270141148.mha")
print(image)
# Out:
# Image (0000019A2440D300)
#   RTTI typeinfo:   class itk::Image<short,3>
#   Reference Count: 1
#   Modified Time: 5864
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 5834
#   UpdateMTime: 5860
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [128, 128, 64]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [128, 128, 64]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [128, 128, 64]
#   Spacing: [0.820312, 0.820312, 1.25]
#   Origin: [37.6373, -123.867, -304.25]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 0.820312 0 0
# 0 0.820312 0
# 0 0 1.25
#
#   PointToIndexMatrix:
# 1.21905 0 0
# 0 1.21905 0
# 0 0 0.8
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (0000019A1866FFA0)
#       RTTI typeinfo:   class itk::ImportImageContainer<unsigned __int64,short>
#       Reference Count: 1
#       Modified Time: 5857
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0000019A2E8BE040
#       Container manages memory: true
#       Size: 1048576
#       Capacity: 1048576

# %%
image = sitk.GetArrayFromImage(image)
axial, coronal, sagittal = get_orthogonal_patches(image)
plt.imshow(axial, cmap='gray')
plt.show()
plt.imshow(coronal, cmap='gray')
plt.show()
plt.imshow(sagittal, cmap='gray')
plt.show()
