# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
sns.set_style("white")

# %%
workspace = Path("C:/Users/Kieran/Documents/LUNA23-ISMI-Group7")
# workspace = Path("D:/LUNA23-ISMI-Group7")

# %%
model_id = "20230524_2_multitask_model_5fold/fold1/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID2 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230526_8_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID8 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
average_cum_score_2 = np.average(cumulative_score_ID2.reshape(-1, 10), axis=1)
average_cum_score_8 = np.average(cumulative_score_ID8.reshape(-1, 10), axis=1)
epochs = np.arange(0, 400, 10)
plt.plot(epochs, average_cum_score_2, label="No shared weights")
plt.plot(epochs, average_cum_score_8, label="Shared classification weights")

plt.legend()
plt.title("Shared classification weights")
plt.ylim([0.6, 0.9])
# plt.ylim([0, 1])
sns.despine()

# %%
model_id = "20230527_12_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID12 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230527_14_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID14 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230527_15_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID15 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
average_cum_score_12 = np.average(cumulative_score_ID12.reshape(-1, 10), axis=1)
average_cum_score_14 = np.average(cumulative_score_ID14.reshape(-1, 10), axis=1)
average_cum_score_15 = np.average(cumulative_score_ID15.reshape(-1, 10), axis=1)
epochs = np.arange(0, 400, 10)
plt.plot(epochs, average_cum_score_12, label="Weight decay = 1e-4")
plt.plot(epochs, average_cum_score_14, label="Weight decay = 1e-3")
plt.plot(epochs, average_cum_score_15, label="Weight decay = 1e-2")

plt.legend()
plt.title("Weight decay experiment")
plt.ylim([0.6, 0.9])

sns.despine()

# %%
model_id = "20230527_12_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID12 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230527_16_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID16 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
average_cum_score_12 = np.average(cumulative_score_ID12.reshape(-1, 10), axis=1)
average_cum_score_16 = np.average(cumulative_score_ID16.reshape(-1, 10), axis=1)
# average_cum_score_17 = np.average(cumulative_score_ID17.reshape(-1, 10), axis=1)
epochs = np.arange(0, 400, 10)
plt.plot(epochs, average_cum_score_12, label="Label smoothing = 0.1")
plt.plot(epochs, average_cum_score_16, label="Label smoothing = 0.3")
# plt.plot(epochs, average_cum_score_17, label="Overall score model ID 15")

plt.legend()
plt.title("Label smoothing experiment")
plt.ylim([0.6, 0.9])

sns.despine()

# %%
model_id = "20230528_20_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID20 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230529_22_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID22 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230529_23_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID23 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
model_id = "20230529_24_multitask_model/fold0/"
metrics = np.load(workspace / "results" / model_id / "metrics.npy", allow_pickle=True).item()

task_specific_metrics = {
    "segmentation": "dice",
    "malignancy": "auc",
    "nodule-type": "balanced_accuracy"
}

tasks = ["malignancy", "nodule-type", "segmentation"]

dice_score = []
auc_score = []
balanced_accuracy_score = []

[dice_score.append(metrics['validation'][i]['segmentation']['dice']) for i in range(len(metrics['validation']))]
[auc_score.append(metrics['validation'][i]['malignancy']['auc']) for i in range(len(metrics['validation']))]
[balanced_accuracy_score.append(metrics['validation'][i]['nodule-type']['balanced_accuracy']) for i in range(len(metrics['validation']))]

dice_score = np.array(dice_score)
auc_score = np.array(auc_score)
balanced_accuracy_score = np.array(balanced_accuracy_score)

cumulative_score_ID24 = 0.5 * auc_score + 0.25 * balanced_accuracy_score + 0.25 * dice_score

# %%
average_cum_score_20 = np.average(cumulative_score_ID20.reshape(-1, 10), axis=1)
average_cum_score_22 = np.average(cumulative_score_ID22.reshape(-1, 10), axis=1)
average_cum_score_23 = np.average(cumulative_score_ID23.reshape(-1, 10), axis=1)
average_cum_score_24 = np.average(cumulative_score_ID24.reshape(-1, 10), axis=1)

epochs = np.arange(0, 400, 10)

plt.plot(epochs, average_cum_score_20, label="Loss balance = 1:1:1")
plt.plot(epochs, average_cum_score_22, label="Loss balance = 1:1:2")
plt.plot(epochs, average_cum_score_23, label="Loss balance = 1:1:3")
plt.plot(epochs, average_cum_score_24, label="Loss balance = 1:1:4")

plt.legend()
plt.title("Loss balancing experiment")
plt.ylim([0.6, 0.9])

sns.despine()
